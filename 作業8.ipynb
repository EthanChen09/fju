# %%
import numpy as np
import scipy.stats as si


S = 90      # Spot price
K = 100     # Strike price
r = 0.01    # Risk-free rate
sigma = 0.3 # Volatility

# Different maturities
T_list= [1, 0.9, 0.5, 0.3, 0.1]


call_prices = []
for T in T_values:
    d1 = (np.log(S / K) + (r + 0.5 * sigma ** 2) * T) / (sigma * np.sqrt(T))
    d2 = d1 - sigma * np.sqrt(T)
    call = S * si.norm.cdf(d1) - K * np.exp(-r * T) * si.norm.cdf(d2)
    call_prices.append((T, call))

call_prices
# Out:
# [(1, 7.325316316806504),
#  (0.9, 6.750179641562781),
#  (0.5, 4.128125544870759),
#  (0.3, 2.5241688673926532),
#  (0.1, 0.6167434536213108)]

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))
plt.plot(T_list, call_prices, marker='o')
plt.title('European Call Option Price vs Time to Maturity')
plt.xlabel('Time to Maturity (T)')
plt.ylabel('Call Option Price')
plt.grid(True)
plt.gca().invert_xaxis()  # Optional: To show T from 1 to 0.1 left to right
plt.show()
